# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../threads_python_report.csv", sep=";")

# %%
df  = df.drop(columns=["time"])

# %%
df = df.groupby(["n", "array_size"]).mean().reset_index()

# %%
array_100 = df[df["array_size"] == 100]
array_1000 = df[df["array_size"] == 1000]
array_100000 = df[df["array_size"] == 100000]
array_1000000 = df[df["array_size"] == 1000000]

# %%
def plot_graph(df):
    df.plot(x="n", y="time_elapsed", marker="o", legend=False)

    sort_type = "Timsort sort"
    n_type = "Thread"

    plt.title(f'{sort_type} perfomance with {n_type} x time')
    plt.xlabel(f'Number of {n_type}')
    plt.ylabel('Time in ms')

    plt.show()

# %%
plot_graph(array_100)

# %%
plot_graph(array_1000)

# %%
plot_graph(array_100000)

# %%
plot_graph(array_1000000)
